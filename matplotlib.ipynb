# %% [markdown]
# <a href="https://colab.research.google.com/github/2101327/0912/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
t=np.arange(0,2,0.01)
s=1+np.cos(2*np.pi*t)
fig,ax=plt.subplots()
ax.plot(t,s)
ax.set(xlabel='x',ylabel='y',title='y=cos(2πx)+1')
ax.grid()
plt.show()
